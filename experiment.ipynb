# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageOps 

from convolution import *
from gaussian import *
from image_pyramid import *

from blob import *

# %%
# creating a image1 object 
im1 = Image.open("sample.jpg") 
 
# applying grayscale method 
im2 = ImageOps.grayscale(im1)

# %%
plt.imshow(im2, cmap='gray')

# %%
a = np.array(im2)
print(a.shape)

pyramid, sigmas = get_pyramid(a)
# Out:
# (399, 600)
# Octave number : 0
# Octave Sigma:  1
# Actual Sigma:  1
# Octave number : 0
# Octave Sigma:  1.2599210498948732
# Actual Sigma:  1.2599210498948732
# Octave number : 0
# Octave Sigma:  1.5874010519681994
# Actual Sigma:  1.5874010519681994
# Octave number : 0
# Octave Sigma:  2
# Actual Sigma:  2
# ---------------------------------------------------------------
# Octave number : 1
# Octave Sigma:  1
# Actual Sigma:  2
# Octave number : 1
# Octave Sigma:  1.2599210498948732
# Actual Sigma:  2.5198420997897464
# Octave number : 1
# Octave Sigma:  1.5874010519681994
# Actual Sigma:  3.1748021039363987
# Octave number : 1
# Octave Sigma:  2
# Actual Sigma:  4
# ---------------------------------------------------------------
# Octave number : 2
# Octave Sigma:  1
# Actual Sigma:  4
# Octave number : 2
# Octave Sigma:  1.2599210498948732
# Actual Sigma:  5.039684199579493
# Octave number : 2
# Octave Sigma:  1.5874010519681994
# Actual Sigma:  6.3496042078727974
# ...

# %%
laplacians = laplacian_of_gaussian(pyramid)
visualise_blobs(laplacians, sigmas)
# Out:
# Actual Sigma:  1
# Actual Sigma:  1.2599210498948732
# Actual Sigma:  1.5874010519681994
# Actual Sigma:  2
# Actual Sigma:  2.5198420997897464
# Actual Sigma:  3.1748021039363987
# Actual Sigma:  4
# Actual Sigma:  5.039684199579493
# Actual Sigma:  6.3496042078727974
# Actual Sigma:  8
# Actual Sigma:  10.079368399158986
# Actual Sigma:  12.699208415745595
# Actual Sigma:  16
# Actual Sigma:  20.15873679831797
# Actual Sigma:  25.39841683149119

# %%
print(len(pyramid),len(pyramid[0]))
print(len(laplacians),len(laplacians[0]))
print(len(sigmas),len(sigmas[0]))
# Out:
# 5 4
# 5 3
# 5 4

# %%
features = get_features(laplacians, pyramid, sigmas, 16)

# %%
print(len(features.values()))

print(features.keys())
# Out:
# 15
# dict_keys([1, 1.2599210498948732, 1.5874010519681994, 2, 2.5198420997897464, 3.1748021039363987, 4, 5.039684199579493, 6.3496042078727974, 8, 10.079368399158986, 12.699208415745595, 16, 20.15873679831797, 25.39841683149119])

# %%
visualise_features(features)
# Out:
# Actual Sigma:  1
# Actual Sigma:  1.2599210498948732
# Actual Sigma:  1.5874010519681994
# Actual Sigma:  2
# Actual Sigma:  2.5198420997897464
# Actual Sigma:  3.1748021039363987
# Actual Sigma:  4
# Actual Sigma:  5.039684199579493
# Actual Sigma:  6.3496042078727974
# Actual Sigma:  8
# Actual Sigma:  10.079368399158986
# Actual Sigma:  12.699208415745595
# Actual Sigma:  16
# Actual Sigma:  20.15873679831797
# Actual Sigma:  25.39841683149119
